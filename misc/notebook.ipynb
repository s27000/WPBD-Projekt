# %%
import pandas as pd
df = pd.read_parquet("db_state_1.parquet")  # uses pyarrow under the hood
print(df.info())
print('\n', df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   idAlbumu         1 non-null      int32
#  1   tytul            1 non-null      str
#  2   wykonawca        1 non-null      str
#  3   gatunek          1 non-null      str
#  4   wytwornia        1 non-null      str
#  5   dataWydania      1 non-null      str
#  6   cena             0 non-null      float64
#  7   kafka_timestamp  1 non-null      datetime64[ns]
#  8   processed_at     1 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int32(1), str(5)
# memory usage: 245.0 bytes
# None
#
#     idAlbumu     tytul wykonawca       gatunek wytwornia dataWydania  cena  \
# 0        11  Megadeth  Megadeth  Thrash Metal   Elektra  2026-01-26   NaN
#
#           kafka_timestamp            processed_at
# 0 2026-04-08 18:07:11.804 2026-04-08 18:07:20.005

# %%
import pandas as pd
df = pd.read_parquet("db_state_2.parquet")  # uses pyarrow under the hood
print(df.info())
print('\n', df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   idZamowienia            13 non-null     int32
#  1   KlientId                13 non-null     str
#  2   AlbumId                 13 non-null     str
#  3   adresDostawy            13 non-null     str
#  4   dataZlozeniaZamowienia  13 non-null     str
#  5   kafka_timestamp         13 non-null     datetime64[ns]
#  6   processed_at            13 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), int32(1), str(4)
# memory usage: 1.2 KB
# None
#
#      idZamowienia KlientId AlbumId              adresDostawy  \
# 0              1        1       1     ul. Długa 5, Warszawa
# 1              2        1       2     ul. Długa 5, Warszawa
# 2              3        1       3     ul. Długa 5, Warszawa
# 3              4        1       8  ul. Wiejska 10, Warszawa
# ...
